# %% [markdown]
# # Matplotlib 3d plotting

# %%
# %%time
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.pyplot import imshow

# %matplotlib inline

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Out:
# CPU times: user 27.4 ms, sys: 1.85 ms, total: 29.3 ms
# Wall time: 28.8 ms

# %%
# %%time
from PIL import Image
import numpy as np

img = Image.open("images/IMG_20170408_131933.jpg")
img.load()
data = np.asarray( img, dtype="int32" )
# Out:
# CPU times: user 560 ms, sys: 84 ms, total: 644 ms
# Wall time: 645 ms

# %%
imshow(np.asarray(img))

# %%
data[1]
# Out:
# array([[ 82, 138, 223],
#        [ 84, 140, 225],
#        [ 84, 140, 225],
#        ...,
#        [ 68, 118, 187],
#        [ 72, 122, 191],
#        [ 70, 120, 189]], dtype=int32)
